# %% [markdown]
# # Data science in Python
#
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/240px-Python-logo-notext.svg.png" /></center>

# %% [markdown]
# ## Aims
#
# This course will cover concepts and strategies for working with data **more effectively** in Python with the aim of:
#
# - Writing **reusable** code, using **functions** and **libraries**
# - Acquiring a working knowledge of **key concepts** which are prerequisites for advanced programming in Python like writing classes to build objects
# - During this course you will learn about:
#     - Manipulating data using Pandas
#     - Visualising data with Matplotlib
#     - Working with biological data using BioPython

# %% [markdown]
# ## Learning objectives
# - **Use** third-party Python libraries: Pandas, Matplotlib & BioPython
# - **Solve** more complex exercises using these concepts

# %% [markdown]
# ## Course schedule - day 2
#
#
# - 09:30-09:45: [0:15] **Introduction**
# - 09:45-11:00: [1:15] **Session 2.1** - Manipulating data with Pandas
# - 11:00-11:15: [0:15] *break*
# - 11:15-12:30: [1:15] **Session 2.2** - Visualising data with Matplotlib
# - 12:30-13:30: [1:00] *lunch break*
# - 13:30-14:45: [1:15] **Session 2.3** - Working with biological data using BioPython
# - 14:45-15:00: [0:15] *break*
# - 15:00-16:15: [1:15] **Session 2.4** - Creating a data project report using Jupyter
# - 16:15-16:30: [0:15] **Conclusion**

# %% [markdown]
# ## Course materials
#
# - The course materials is accessible on GitHub:
#     - https://github.com/pycam/python-data-science
# - We’d like you to follow along with the example code as we go through the material, and attempt the exercises to practice what you’ve learned
# - If you have specific projects/problems that you think could be attempted using Python, we are happy to (try to) help during the exercises. Just let us know!

# %% [markdown]
# ## Feedback
#
# - Questions are welcome at any point!
# - We use a two colour post-it system:
#   - **green** when exercise is done; and
#   - **red/pink** when you need help

# %% [markdown]
# ## Next session
#
# Go to our next notebook: [Session 2.1: Data manipulation with Pandas](21_python_data.ipynb)
